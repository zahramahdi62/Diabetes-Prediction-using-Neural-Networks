# %%
#فراخوانی کتابخانه ها
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import linear_model

# %%
# خواندن اطلاعات از Data set
data = pd.read_csv('cancer.csv')

# %%
#دیدن قسمتی از data set
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
#دیدن یکسری ار اطلاعات data set
#data.info()
data.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
#حذف بعضی ار اطلاعات  از data set
data=data.drop(['Unnamed: 32','id'],axis=1)

# %%
#تبدیل خروجی به صفر و یک
data.diagnosis=[1 if each=="M" else 0 for each in data.diagnosis]

# %%
#دادن  ابعاد و خروجی به x,y
y=data.diagnosis
x_data=data.drop(['diagnosis'],axis=1)

# %%
#نرمالایز کردن data set 
x=(x_data-np.min(x_data))/(np.max(x_data)-np.min(x_data))
print(x)
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0       0.004229      0.002440        0.028867   0.235308         0.000028
# 1       0.004835      0.004177        0.031241   0.311707         0.000020
# 2       0.004629      0.004995        0.030559   0.282793         0.000026
# 3       0.002685      0.004791        0.018237   0.090762         0.000033
# 4       0.004770      0.003371        0.031758   0.304890         0.000024
# ..           ...           ...             ...        ...              ...
# 564     0.005068      0.005263        0.033380   0.347673         0.000026
# 565     0.004732      0.006641        0.030842   0.296427         0.000023
# 566     0.003902      0.006601        0.025458   0.201716         0.000020
# 567     0.004843      0.006895        0.032934   0.297367         0.000028
# 568     0.001824      0.005769        0.011265   0.042548         0.000012
#
# ...

# %%
#جدا گردن x,y برای آموزش
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.15,random_state=42)

# %%
#ساخت مدل و آموزش و تعداد تکرار LogisticRegression
model=linear_model.LogisticRegression()
model.max_iter=1000000
model.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=1000000)

# %%
#پیش بینی کردن ربات
robot=model.predict(X_test)
v=y_test==robot
v=v.reset_index()
v=v.diagnosis
n=0
for i in v :
    if i==False : n=+1
print(n,'/',len(v))
# Out:
# 1 / 86
